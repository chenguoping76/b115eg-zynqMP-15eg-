# %% [markdown]
# # usb-web camera 使用demo
# ## 使用logical C270 usb web camera

# %%
from PIL import Image as PIL_Image

# %%
orig_img_path = 'data/record.jpg'

# %%
# !gst-launch-1.0 v4l2src device=/dev/video0 num-buffers=1 ! 'video/x-raw,format=YUY2,width=1280, height=720, framerate=5/1' ! jpegenc ! filesink location=./data/file_1280_720.jpg
# Out:
# Setting pipeline to PAUSED ...
# Pipeline is live and does not need PREROLL ...
# Pipeline is PREROLLED ...
# Setting pipeline to PLAYING ...
# New clock: GstSystemClock
# Got EOS from element "pipeline0".
# Execution ended after 0:00:02.630274599
# Setting pipeline to NULL ...
# Freeing pipeline ...

# %%
img = PIL_Image.open('./data/file_1280_720.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0xFFFFAC43B670>

# %%
bw_img = img.convert("L")
bw_img
# Out:
# <PIL.Image.Image image mode=L size=1280x720 at 0xFFFFAC43B4F0>

# %%
rot_img = img.rotate(45)
rot_img
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0xFFFFAC3E34C0>
